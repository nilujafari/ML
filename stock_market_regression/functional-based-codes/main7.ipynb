# %%
from utils import read_and_clean_data

# %%
amazon_data = read_and_clean_data(file_path="../dataset/portfolio_data.csv", drop_list=["DPZ", "BTC", "NFLX"])
# Out:
# Number of null data: Date    0
# AMZN    0
# dtype: int64
# Number of duplicated data: 0
