# %% [markdown]
# ## spaghatti coding
#
#
# function => X
# class => X

# %% [markdown]
# ## functional programming
#
#
# function => OK
# class => X

# %% [markdown]
# ## Object oriented programming
#
# function => OK
# class => OK

# %%
amazon_data = 5
print(amazon_data)

def test_func():
    amazon_data = 2
    print(amazon_data)

test_func()
print(amazon_data)
# Out:
# 5
# 2
# 3
