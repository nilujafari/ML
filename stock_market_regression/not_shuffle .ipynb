# %% [markdown]
# ### Shuffle = False

# %% [markdown]
# ##### Predict the next-day Amazon stock price using the previous 30 days of data with six regression models.The data is kept in time order without shuffling and the models are compared using MAE, MSE, RMSE, and R².

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
amazon_data = pd.read_csv("./dataset/portfolio_data.csv")

# %%
amazon_data = amazon_data.drop(["DPZ", "BTC", "NFLX"], axis=1)

# %%
amazon_data.head()
# Out:
#        Date        AMZN
# 0  5/1/2013  248.229996
# 1  5/2/2013  252.550003
# 2  5/3/2013  258.049988
# 3  5/6/2013  255.720001
# 4  5/7/2013  257.730011

# %%
type(amazon_data)
# Out:
# pandas.DataFrame

# %%
amazon_data.shape
# Out:
# (1520, 2)

# %%
amazon_data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1520 entries, 0 to 1519
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    1520 non-null   str
#  1   AMZN    1520 non-null   float64
# dtypes: float64(1), str(1)
# memory usage: 23.9 KB

# %%
amazon_data.isnull().sum()
# Out:
# Date    0
# AMZN    0
# dtype: int64

# %%
amazon_data.duplicated().sum()
# Out:
# np.int64(0)

# %%
amazon_data["Date"] = pd.to_datetime(amazon_data["Date"])

# %% [markdown]
# #### This chart shows Amazon stock prices from 2013 to 2019

# %%
plt.figure(figsize=(16, 8))
plt.plot(amazon_data["Date"], amazon_data["AMZN"])
plt.title("Amazon Stock Price")
plt.xlabel("Date")
plt.ylabel("Price")
plt.grid()
plt.show()

# %%
# test
year_avrg = amazon_data.groupby(amazon_data["Date"].dt.year)["AMZN"].mean()
plt.figure(figsize=(10, 5))
plt.bar(year_avrg.index, year_avrg.values)
plt.title("Average Amazon Stock Price by Year")
plt.xlabel("Year")
plt.ylabel("Average Price")
plt.grid(axis="y")
plt.show()

# %%
## Holidays just sat and sun
pd.date_range(start="7/1/2017", end="7/21/2017", freq="B")
# Out:
# DatetimeIndex(['2017-07-03', '2017-07-04', '2017-07-05', '2017-07-06',
#                '2017-07-07', '2017-07-10', '2017-07-11', '2017-07-12',
#                '2017-07-13', '2017-07-14', '2017-07-17', '2017-07-18',
#                '2017-07-19', '2017-07-20', '2017-07-21'],
#               dtype='datetime64[us]', freq='B')

# %% [markdown]
# ##### The data is prepared using a 30-day sliding window to predict the next day is Amazon stock price.

# %%
amazon_price = amazon_data["AMZN"].values
print(type(amazon_price))

X = []
y = []
input_days = 30
output_days = 1
print(f"Expected generated data length should be: {len(amazon_price) - input_days - output_days + 1}")

counter = 0
for index in range(len(amazon_price) - input_days - output_days + 1):
    x_start_index = index
    x_end_index = index + input_days

    X.append(amazon_price[x_start_index : x_end_index])
    y.append(amazon_price[x_end_index])

    counter += 1
    if counter < 10:
        print(f"x_start_index: {x_start_index} - x_end_index: {x_end_index - output_days} - y_index: {x_end_index}")
# Out:
# <class 'numpy.ndarray'>
# Expected generated data length should be: 1490
# x_start_index: 0 - x_end_index: 29 - y_index: 30
# x_start_index: 1 - x_end_index: 30 - y_index: 31
# x_start_index: 2 - x_end_index: 31 - y_index: 32
# x_start_index: 3 - x_end_index: 32 - y_index: 33
# x_start_index: 4 - x_end_index: 33 - y_index: 34
# x_start_index: 5 - x_end_index: 34 - y_index: 35
# x_start_index: 6 - x_end_index: 35 - y_index: 36
# x_start_index: 7 - x_end_index: 36 - y_index: 37
# x_start_index: 8 - x_end_index: 37 - y_index: 38

# %%
#test 
sample_index = 0
plt.plot(X[sample_index], marker= 'o')
plt.plot(input_days, y[sample_index], 'ro')
plt.xlabel("Input Days")
plt.ylabel("Price")
plt.title("Input Days and Output Days")
plt.show()

# %%
# test
plt.figure(figsize=(15,6))
plt.plot(amazon_price, label="Original Data")
plt.scatter(range(input_days, len(amazon_price)), y, color="red", s=5, label="Target (y)")
plt.xlabel("Days")
plt.ylabel("Price")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ### Train & Test split

# %% [markdown]
# ##### The data is split into training and testing sets without shuffling to preserve the time order.

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# %% [markdown]
# ### pre-processing

# %% [markdown]
# ##### The data is normalized using MinMaxScaler to scale the input features and target values to a common range.

# %%
from sklearn.preprocessing import MinMaxScaler

feature_scaler = MinMaxScaler()
X_train_norm = feature_scaler.fit_transform(X_train)
X_test_norm = feature_scaler.transform(X_test)

target_scaler = MinMaxScaler()
y_train_norm = target_scaler.fit_transform(np.reshape(y_train, (-1, 1)))
y_test_norm = target_scaler.transform(np.reshape(y_test, (-1, 1)))

# %%
print(f"Input Days: {input_days} - Output Days: {output_days}")
print(f"X_train Shape: {X_train_norm.shape} - X_test Shape: {X_test_norm.shape}")
print(f"y_train Shape: {y_train_norm.shape} - y_test Shape: {y_test_norm.shape}")
# Out:
# Input Days: 30 - Output Days: 1
# X_train Shape: (1192, 30) - X_test Shape: (298, 30)
# y_train Shape: (1192, 1) - y_test Shape: (298, 1)

# %% [markdown]
# ### Regression Models

# %% [markdown]
# #### 1.Linear Regression

# %%
from sklearn.linear_model import LinearRegression

linear_model = LinearRegression()
linear_model.fit(X_train_norm, y_train_norm)
# Out:
# LinearRegression()

# %%
linear_pred = linear_model.predict(X_test_norm)

# %%
print(f"linear Predicted Shape: {linear_pred.shape}")
# Out:
# linear Predicted Shape: (298, 1)

# %%
#test
selected_index = 5

selected_x = X_test_norm[selected_index]
selected_y = y_test_norm[selected_index]
selected_pred = linear_pred[selected_index]

print(f"Selected X: {selected_x}")
print(f"Selected y: {selected_y}")
print(f"Selected predict: {selected_pred}")
# Out:
# Selected X: [1.07928671 1.02473893 1.04633631 0.98948815 1.02169051 0.98215656
#  0.91569036 0.90641211 0.945625   0.96940672 1.00013458 1.00914098
#  0.99814988 1.01468272 1.02693523 1.02897023 1.04115828 1.05015745
#  1.04198187 1.03666382 1.00865078 1.01222495 1.01912824 1.0124896
#  1.01836979 1.02384942 1.04550327 1.06108657 1.05153238 1.04211422]
# Selected y: [1.02928456]
# Selected predict: [1.04101625]

# %%
# # Plot only the 100 samples
# n = 100
# error = (y_test_norm[:n] - linear_pred[:n]).ravel()

# plt.figure(figsize=(12, 6))
# plt.bar(range(n), error)
# plt.axhline(0, linestyle="--")
# plt.title("Prediction Error - Linear Regression")
# plt.xlabel("Test Samples")
# plt.ylabel("Prediction Error")
# plt.grid()
# plt.show()

# %%
test_dates = amazon_data["Date"].iloc[input_days + len(y_train):input_days + len(y_train) + len(y_test)]

# %%
real_price = target_scaler.inverse_transform(y_test_norm.reshape(-1, 1)).ravel()
linear_price = target_scaler.inverse_transform(linear_pred.reshape(-1, 1)).ravel()

plt.figure(figsize=(16, 6))

test_dates = amazon_data["Date"].iloc[input_days + len(y_train):input_days + len(y_train) + len(y_test)]

plt.subplot(1, 2, 1)
plt.plot(test_dates, real_price, label="Real Price", linewidth=2)
plt.plot(test_dates, linear_price, label="Predicted Price", linewidth=2)
plt.title("Linear Regression - Test Set")
plt.xlabel("Date")
plt.ylabel("Price")
plt.legend()
plt.grid()
plt.xticks(rotation=45)


plt.subplot(1, 2, 2)
plt.plot(amazon_data["Date"], amazon_data["AMZN"])
plt.title("Amazon Stock Price")
plt.xlabel("Date")
plt.ylabel("Real Price")
plt.grid()

plt.tight_layout()
plt.show()

# %%
linear_error = y_test_norm - linear_pred
# print(error)
plt.figure(figsize=(10, 6))
plt.hist(linear_error, bins=20)
plt.title("linear Prediction Error Histogram")
plt.xlabel("Prediction Error")
plt.ylabel("Frequency")
plt.axvline(0, linestyle="--")
plt.grid()
plt.show()

# %% [markdown]
# ### 2.K-Neighbors Regressor

# %%
from sklearn.neighbors import KNeighborsRegressor

knn_model = KNeighborsRegressor()
knn_model.fit(X_train_norm, y_train_norm)
# Out:
# KNeighborsRegressor()

# %%
knn_pred = knn_model.predict(X_test_norm)

# %%
real_price = target_scaler.inverse_transform(y_test_norm.reshape(-1, 1)).ravel()
knn_price = target_scaler.inverse_transform(knn_pred.reshape(-1, 1)).ravel()

plt.figure(figsize=(16, 6))

test_dates = amazon_data["Date"].iloc[input_days + len(y_train):input_days + len(y_train) + len(y_test)]

plt.subplot(1, 2, 1)
plt.plot(test_dates, real_price, label="Real Price", linewidth=2)
plt.plot(test_dates, knn_price, label="Predicted Price", linewidth=2)
plt.title("KNeighbors Regressor - Test Set")
plt.xlabel("Date")
plt.ylabel("Price")
plt.legend()
plt.grid()
plt.xticks(rotation=45)


plt.subplot(1, 2, 2)
plt.plot(amazon_data["Date"], amazon_data["AMZN"])
plt.title("Amazon Stock Price")
plt.xlabel("Date")
plt.ylabel("Real Price")
plt.grid()

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 3.Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor

dt_model = DecisionTreeRegressor(max_depth=5, min_samples_split=20, min_samples_leaf=10)
dt_model.fit(X_train_norm, y_train_norm)
# Out:
# DecisionTreeRegressor(max_depth=5, min_samples_leaf=10, min_samples_split=20)

# %%
dt_pred = dt_model.predict(X_test_norm)

# %%
real_price = target_scaler.inverse_transform(y_test_norm.reshape(-1, 1)).ravel()
dt_price = target_scaler.inverse_transform(dt_pred.reshape(-1, 1)).ravel()
plt.plot(real_price, label="Real Price")
plt.plot(dt_price, label="Predicted Price")
plt.title("Amazon Stock Price (Decision Tree Regressor)")
plt.xlabel("Samples Index")
plt.ylabel("Price")
plt.legend(loc='upper right')
plt.grid()
plt.show()

# %%
dt_error = y_test_norm - dt_pred
# print(error)
plt.figure(figsize=(10, 6))
plt.hist(dt_error, bins=20)
plt.title("Decition Tree Prediction Error Histogram")
plt.xlabel("Prediction Error")
plt.ylabel("Frequency")
plt.axvline(0, linestyle="--")
plt.grid()
plt.show()

# %% [markdown]
# ### 4.Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor

rf_model = RandomForestRegressor(n_estimators=200, max_depth=8, min_samples_leaf=5)
rf_model.fit(X_train_norm, y_train_norm)
# Out:
# e:\Python Git\ML\breast_cancer_classification\.venv\Lib\site-packages\sklearn\base.py:1336: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestRegressor(max_depth=8, min_samples_leaf=5, n_estimators=200)

# %%
rf_pred = rf_model.predict(X_test_norm)

# %%
real_price = target_scaler.inverse_transform(y_test_norm.reshape(-1, 1)).ravel()
rf_price = target_scaler.inverse_transform(rf_pred.reshape(-1, 1)).ravel()

plt.plot(real_price, label="Real Price")
plt.plot(rf_price, label="Predicted Price")
plt.title("Amazon Stock Price (Random Forest Regressor)")
plt.xlabel("Samples Index")
plt.ylabel("Price")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ### 5.Support Vector Regression

# %%
from sklearn.svm import SVR

svr_model = SVR(C=100, kernel="linear") #epsilon=1, gamma="scale"
svr_model.fit(X_train_norm, y_train_norm)
# Out:
# e:\Python Git\ML\breast_cancer_classification\.venv\Lib\site-packages\sklearn\utils\validation.py:1352: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVR(C=100, kernel='linear')

# %%
svr_pred = svr_model.predict(X_test_norm)

# %%
plt.figure(figsize=(16,6))
plt.subplot(1, 2, 1)

plt.plot(amazon_data["Date"].iloc[:len(y_train)], y_train_norm, color="black", label="Train (Real)")
plt.plot(test_dates, y_test_norm, color="blue", alpha=0.3, label="Test (Real)")
plt.plot(test_dates, svr_pred, color="orange", label="Predicted")
plt.title("Amazon Stock Price (SVR)")
plt.xlabel("Date")
plt.ylabel("Normalize Price")
plt.legend()
plt.grid()
plt.xticks(rotation=45)


plt.subplot(1, 2, 2)
plt.plot(amazon_data["Date"], amazon_data["AMZN"])
plt.title("Amazon Stock Price")
plt.xlabel("Date")
plt.ylabel("Real Price")
plt.grid()

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 6.MLP Regression(ANN)

# %%
from sklearn.neural_network import MLPRegressor
mlp_model = MLPRegressor()
mlp_model.fit(X_train_norm, y_train_norm)
# Out:
# e:\Python Git\ML\breast_cancer_classification\.venv\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1775: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# MLPRegressor()

# %%
mlp_pred = mlp_model.predict(X_test_norm)

# %%
real_price = target_scaler.inverse_transform(y_test_norm.reshape(-1, 1)).ravel()
mlp_price = target_scaler.inverse_transform(mlp_pred.reshape(-1, 1)).ravel()

plt.figure(figsize=(16, 6))

test_dates = amazon_data["Date"].iloc[input_days + len(y_train):input_days + len(y_train) + len(y_test)]

plt.subplot(1, 2, 1)
plt.plot(test_dates, real_price, label="Real Price", linewidth=2)
plt.plot(test_dates, mlp_price, label="Predicted Price", linewidth=2)
plt.title("MLP Regression(ANN)- Test Set")
plt.xlabel("Date")
plt.ylabel("Price")
plt.legend()
plt.grid()
plt.xticks(rotation=45)


plt.subplot(1, 2, 2)
plt.plot(amazon_data["Date"], amazon_data["AMZN"])
plt.title("Amazon Stock Price(ANN)")
plt.xlabel("Date")
plt.ylabel("Real Price")
plt.grid()
plt.tight_layout()
plt.show()

# %%
mlp_error = y_test_norm - mlp_pred
# print(error)
plt.figure(figsize=(10, 6))
plt.hist(mlp_error, bins=20)
plt.title("MLP Prediction Error Histogram")
plt.xlabel("Prediction Error")
plt.ylabel("Frequency")
plt.axvline(0, linestyle="--")
plt.grid()
plt.show()

# %% [markdown]
# ##### Six regression models are used to predict the next-day Amazon stock price: Linear Regression, SVR, Decision Tree, Random Forest, KNN, and ANN.

# %% [markdown]
# ### Comparison of Regression Models

# %%
real_price = target_scaler.inverse_transform(y_test_norm.reshape(-1, 1)).ravel()
linear_price = target_scaler.inverse_transform(linear_pred.reshape(-1, 1)).ravel()
knn_price = target_scaler.inverse_transform(knn_pred.reshape(-1, 1)).ravel()
dt_price = target_scaler.inverse_transform(dt_pred.reshape(-1, 1)).ravel()
rf_price = target_scaler.inverse_transform(rf_pred.reshape(-1, 1)).ravel()
svr_price = target_scaler.inverse_transform(svr_pred.reshape(-1, 1)).ravel()
mlp_price = target_scaler.inverse_transform(mlp_pred.reshape(-1, 1)).ravel()

samples = [0, 50, 100, 200, 150, 250, 290]
plt.figure(figsize=(10,6))
plt.scatter(samples, real_price[samples], label="Real", s=120, color= 'black')

plt.scatter(samples, linear_price[samples], label="Linear")
plt.scatter(samples, knn_price[samples], label="KNN")
plt.scatter(samples, dt_price[samples], label="Decision Tree")
plt.scatter(samples, rf_price[samples], label="Random Forest")
plt.scatter(samples, svr_price[samples], label="SVR")
plt.scatter(samples, mlp_price[samples], label="ANN")
plt.legend()
plt.xlabel("Sample")
plt.ylabel("Price")
plt.title("Comparison of Models")
plt.grid()
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.plot(y_test_norm, label="Real")
plt.plot(linear_pred, label="Linear")
plt.plot(knn_pred, label="KNN")
plt.plot(dt_pred, label="Decision Tree")
plt.plot(rf_pred, label="Random Forest")
plt.plot(svr_pred, label="SVR")
plt.plot(mlp_pred, label="ANN")
plt.title("Comparison of Regression Models")
plt.xlabel("Test Samples")
plt.ylabel("Stock Price")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# #### Mean absolute error - Mean squared error - R2 score

# %%
from sklearn.metrics import (mean_absolute_error,mean_squared_error,r2_score)

models = ["Linear","KNN","Decision-T","Random-F","SVR","ANN"]
results = pd.DataFrame({"Model":models,
    "MAE":[
        mean_absolute_error(y_test_norm, linear_pred),
        mean_absolute_error(y_test_norm, knn_pred),
        mean_absolute_error(y_test_norm, dt_pred),
        mean_absolute_error(y_test_norm, rf_pred),
        mean_absolute_error(y_test_norm, svr_pred),
        mean_absolute_error(y_test_norm, mlp_pred)],

    "MSE":[
        mean_squared_error(y_test_norm, linear_pred),
        mean_squared_error(y_test_norm, knn_pred),
        mean_squared_error(y_test_norm, dt_pred),
        mean_squared_error(y_test_norm, rf_pred),
        mean_squared_error(y_test_norm, svr_pred),
        mean_squared_error(y_test_norm, mlp_pred)],

    "RMSE":[
        np.sqrt(mean_squared_error(y_test_norm, linear_pred)),
        np.sqrt(mean_squared_error(y_test_norm, knn_pred)),
        np.sqrt(mean_squared_error(y_test_norm, dt_pred)),
        np.sqrt(mean_squared_error(y_test_norm, rf_pred)),
        np.sqrt(mean_squared_error(y_test_norm, svr_pred)),
        np.sqrt(mean_squared_error(y_test_norm, mlp_pred))],

    "R2":[
        r2_score(y_test_norm, linear_pred),
        r2_score(y_test_norm, knn_pred),
        r2_score(y_test_norm, dt_pred),
        r2_score(y_test_norm, rf_pred),
        r2_score(y_test_norm, svr_pred),
        r2_score(y_test_norm, mlp_pred)]})

print(results.round(4))
# Out:
#         Model     MAE     MSE    RMSE      R2
# 0      Linear  0.0204  0.0008  0.0288  0.9436
# 1         KNN  0.1594  0.0367  0.1916 -1.5005
# 2  Decision-T  0.1763  0.0433  0.2081 -1.9511
# 3    Random-F  0.1661  0.0394  0.1984 -1.6826
# 4         SVR  0.0565  0.0069  0.0830  0.5307
# 5         ANN  0.0587  0.0062  0.0790  0.5750

# %%
models = results["Model"]
n = len(models)
plt.figure(figsize=(12, 5))
plt.bar(np.arange(n), results["MAE"], label="MAE")
plt.bar(np.arange(n) + n, results["MSE"], label="MSE")
plt.bar(np.arange(n) + 2*n, results["RMSE"], label="RMSE")
plt.xticks(np.arange(3*n), list(models) * 3, rotation=45)
plt.xlabel("Regression Models")
plt.ylabel("Metric Value")
plt.title("Comparison of Regression Models")
plt.legend()
plt.grid(axis="y")
plt.tight_layout()
plt.show()

# %%
models = results["Model"]
x = np.arange(len(models))
fig, ax = plt.subplots(1, 3, figsize=(15, 5))
# MAE
ax[0].bar(x, results["MAE"])
ax[0].set_title("MAE")
ax[0].set_xticks(x)
ax[0].set_xticklabels(models, rotation=45)
ax[0].grid(axis="y")
# MSE
ax[1].bar(x, results["MSE"],color="orange")
ax[1].set_title("MSE")
ax[1].set_xticks(x)
ax[1].set_xticklabels(models, rotation=45)
ax[1].grid(axis="y")
# RMSE
ax[2].bar(x, results["RMSE"], color="green")
ax[2].set_title("RMSE")
ax[2].set_xticks(x)
ax[2].set_xticklabels(models, rotation=45)
ax[2].grid(axis="y")
plt.tight_layout()
plt.show()

# %%
import json

plot_data = {
    "models": results["Model"].tolist(),
    "MAE": results["MAE"].tolist(),
    "MSE": results["MSE"].tolist(),
    "RMSE": results["RMSE"].tolist()
}

with open("not_shuffle_plot.json", "w") as f:
    json.dump(plot_data, f, indent=4)
