# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
breast_cancer = pd.read_csv('./dataset/breast-cancer.csv')

# %%
breast_cancer.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
breast_cancer.shape
# Out:
# (569, 32)

# %%
breast_cancer.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    str
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
breast_cancer.describe(include='all')
# Out:
#                   id diagnosis  radius_mean  texture_mean  perimeter_mean  \
# count   5.690000e+02       569   569.000000    569.000000      569.000000
# unique           NaN         2          NaN           NaN             NaN
# top              NaN         B          NaN           NaN             NaN
# freq             NaN       357          NaN           NaN             NaN
# mean    3.037183e+07       NaN    14.127292     19.289649       91.969033
# std     1.250206e+08       NaN     3.524049      4.301036       24.298981
# min     8.670000e+03       NaN     6.981000      9.710000       43.790000
# 25%     8.692180e+05       NaN    11.700000     16.170000       75.170000
# 50%     9.060240e+05       NaN    13.370000     18.840000       86.240000
# 75%     8.813129e+06       NaN    15.780000     21.800000      104.100000
# max     9.113205e+08       NaN    28.110000     39.280000      188.500000
#
#           area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# ...

# %%
breast_cancer['diagnosis']
# Out:
# 0      M
# 1      M
# 2      M
# 3      M
# 4      M
#       ..
# 564    M
# 565    M
# 566    M
# 567    M
# 568    B
# Name: diagnosis, Length: 569, dtype: str

# %%
breast_cancer['diagnosis'] = breast_cancer['diagnosis'].map({'M': 1,'B': 0})

# %%
data = breast_cancer.drop(['id', 'diagnosis'], axis= 1) 
target = breast_cancer['diagnosis']

# %%
print(data.shape)
print(target.shape)
# Out:
# (569, 30)
# (569,)

# %%
target.value_counts()
# Out:
# diagnosis
# 0    357
# 1    212
# Name: count, dtype: int64

# %% [markdown]
# # Test , Train

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(data, target, test_size= 0.2) #random_state= , stratify=

# %%
print(f"X_train shape: {X_train.shape} - X_test shape: {X_test.shape}")
print(f"y_train shape: {y_train.shape} - y_test shape: {y_test.shape}")
# Out:
# X_train shape: (455, 30) - X_test shape: (114, 30)
# y_train shape: (455,) - y_test shape: (114,)

# %% [markdown]
# # Histogram

# %%
plt.figure(figsize=(4,4))
sns.countplot(x=y_train, hue=y_train, palette=["#54B170", "#E95D5D"])
plt.title('Distribution of Target Variable')
plt.xlabel('Diagnosis (0=Benign, 1=Malignant)')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # Scaling (pre-processing(0-1))

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range=(0,1))
# print(scaler.min_)
X_train = scaler.fit_transform(X_train)
# print(scaler.data_range_)
X_test  = scaler.transform(X_test)

# %% [markdown]
# # Binary Classification_report

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report

def evaluation_metrics(y_train, y_pred_train, y_test, y_pred_test):
    accuracy_train = accuracy_score(y_train, y_pred_train)
    accuracy_test = accuracy_score(y_test, y_pred_test)
    precision = precision_score(y_test, y_pred_test)
    recall = recall_score(y_test, y_pred_test)
    f1 = f1_score(y_test, y_pred_test)
    print(f'Accuracy Train:{accuracy_train} - Accuracy Test:{accuracy_test} - Precision:{precision} - Recall:{recall} - F1_Score:{f1}')

    print('\nConfusion_Matrix:')
    print(confusion_matrix(y_test, y_pred_test))
    
    print('\nClassification_Report:')
    print(classification_report(y_test, y_pred_test))
    
    return accuracy_train, accuracy_test, precision, recall, f1

# %% [markdown]
# # Model training

# %% [markdown]
# ## 1. KNN (K Nearest Neighbors)

# %%
from sklearn.neighbors import KNeighborsClassifier

scores = []
for k in range(13,17):
    knn = KNeighborsClassifier(n_neighbors= k)
    knn.fit(X_train, y_train)
    score = knn.score(X_test, y_test)
    scores.append(score)
    print(f'K = {k}, Accuracy = {score}')
# Out:
# K = 13, Accuracy = 0.9824561403508771
# K = 14, Accuracy = 0.9736842105263158
# K = 15, Accuracy = 0.9736842105263158
# K = 16, Accuracy = 0.9649122807017544

# %%
knn = KNeighborsClassifier(n_neighbors= 13, weights='uniform', metric='euclidean')
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(metric='euclidean', n_neighbors=13)

# %%
y_pred_train = knn.predict(X_train)
y_pred_test = knn.predict(X_test)

accuracy_train_knn, accuracy_test_knn, precision_knn, recall_knn, f1_knn = evaluation_metrics(y_train, y_pred_train, y_test, y_pred_test)
# Out:
# Accuracy Train:0.9758241758241758 - Accuracy Test:0.9824561403508771 - Precision:1.0 - Recall:0.9534883720930233 - F1_Score:0.9761904761904762
#
# Confusion_Matrix:
# [[71  0]
#  [ 2 41]]
#
# Classification_Report:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99        71
#            1       1.00      0.95      0.98        43
#
#     accuracy                           0.98       114
#    macro avg       0.99      0.98      0.98       114
# weighted avg       0.98      0.98      0.98       114

# %%
import seaborn as sns
confusion_m = confusion_matrix(y_test, y_pred_test)
plt.figure(figsize=(3,2))
sns.heatmap(confusion_m, annot=True, fmt ='d', cmap='hot')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix KNN')
plt.show()

# %% [markdown]
# ## 2. Decition Tree

# %%
from sklearn.tree import DecisionTreeClassifier

best_score = 0
best_parameters = []
for depth in [2, 3, 4, 5, 6]:
    for leaf in [4, 5, 6, 7, 8]:
        for split in [2, 5, 8, 10, 12]:
            dt = DecisionTreeClassifier(max_depth=depth, min_samples_leaf=leaf, min_samples_split=split)
            dt.fit(X_train, y_train)
            y_pred_test = dt.predict(X_test)
            score = accuracy_score(y_test, y_pred_test)
            # print(f'max_depth={depth}, min_samples_leaf={leaf}, min_samples_split={split}, accuracy={score}')

            if score > best_score:
                best_score = score
                best_parameters = {"max_depth":depth, "min_samples_leaf":leaf, "min_samples_split":split}
print('\nBest Accuracy:', best_score)
print('Best Parameters:', best_parameters)
# Out:
# Best Accuracy: 0.9385964912280702
# Best Parameters: {'max_depth': 3, 'min_samples_leaf': 4, 'min_samples_split': 8}

# %%
dt = DecisionTreeClassifier(max_depth= 5, min_samples_leaf=4, min_samples_split=10)
dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=5, min_samples_leaf=4, min_samples_split=10)

# %%
y_pred_train = dt.predict(X_train)
y_pred_test = dt.predict(X_test)

accuracy_train_dt, accuracy_test_dt, precision_dt, recall_dt, f1_dt = evaluation_metrics(y_train, y_pred_train, y_test, y_pred_test)
# Out:
# Accuracy Train:0.9736263736263736 - Accuracy Test:0.9122807017543859 - Precision:0.9024390243902439 - Recall:0.8604651162790697 - F1_Score:0.8809523809523809
#
# Confusion_Matrix:
# [[67  4]
#  [ 6 37]]
#
# Classification_Report:
#               precision    recall  f1-score   support
#
#            0       0.92      0.94      0.93        71
#            1       0.90      0.86      0.88        43
#
#     accuracy                           0.91       114
#    macro avg       0.91      0.90      0.91       114
# weighted avg       0.91      0.91      0.91       114

# %%
import seaborn as sns
confusion_m = confusion_matrix(y_test, y_pred_test)
plt.figure(figsize=(3,2))
sns.heatmap(confusion_m, annot=True, fmt ='d', cmap='hot')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix Decision Tree')
plt.show()

# %% [markdown]
# ## 3. Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

best_score = 0
best_parameters = []
for n in [100, 150, 200]:
    for depth in [5, 10, 15]:
        rf = RandomForestClassifier(n_estimators=n, max_depth=depth)
        rf.fit(X_train, y_train)
        y_pred_test = rf.predict(X_test)
        score = accuracy_score(y_test, y_pred_test)
        print(f'n_estimators={n}, max_depth={depth}, accuracy={score}')

        if score > best_score:
            best_score = score
            best_parameters = {"n_estimators":n, "max_depth":depth}
print('\nBest Accuracy:', best_score)
print('Best Parameters:', best_parameters)
# Out:
# n_estimators=100, max_depth=5, accuracy=0.956140350877193
# n_estimators=100, max_depth=10, accuracy=0.9649122807017544
# n_estimators=100, max_depth=15, accuracy=0.956140350877193
# n_estimators=150, max_depth=5, accuracy=0.9649122807017544
# n_estimators=150, max_depth=10, accuracy=0.9649122807017544
# n_estimators=150, max_depth=15, accuracy=0.9649122807017544
# n_estimators=200, max_depth=5, accuracy=0.956140350877193
# n_estimators=200, max_depth=10, accuracy=0.9649122807017544
# n_estimators=200, max_depth=15, accuracy=0.9649122807017544
#
# Best Accuracy: 0.9649122807017544
# Best Parameters: {'n_estimators': 100, 'max_depth': 10}

# %%
rf = RandomForestClassifier(n_estimators=100, max_depth=5, max_features='sqrt')
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=5)

# %%
y_pred_train = rf.predict(X_train)
y_pred_test = rf.predict(X_test)

accuracy_train_rf, accuracy_test_rf, precision_rf, recall_rf, f1_rf = evaluation_metrics(y_train, y_pred_train, y_test, y_pred_test)
# Out:
# Accuracy Train:0.9956043956043956 - Accuracy Test:0.956140350877193 - Precision:0.9523809523809523 - Recall:0.9302325581395349 - F1_Score:0.9411764705882353
#
# Confusion_Matrix:
# [[69  2]
#  [ 3 40]]
#
# Classification_Report:
#               precision    recall  f1-score   support
#
#            0       0.96      0.97      0.97        71
#            1       0.95      0.93      0.94        43
#
#     accuracy                           0.96       114
#    macro avg       0.96      0.95      0.95       114
# weighted avg       0.96      0.96      0.96       114

# %%
import seaborn as sns
confusion_m = confusion_matrix(y_test, y_pred_test)
plt.figure(figsize=(3,2))
sns.heatmap(confusion_m, annot=True, fmt ='d', cmap='hot')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix Random Forest')
plt.show()

# %% [markdown]
# ## 4. SVM (Support Vector Machine)

# %%
from sklearn.svm import SVC

svm = SVC(kernel='rbf', C=1)
svm.fit(X_train, y_train)
# Out:
# SVC(C=1)

# %%
y_pred_train = svm.predict(X_train)
y_pred_test = svm.predict(X_test)

accuracy_train_svm, accuracy_test_svm, precision_svm, recall_svm, f1_svm = evaluation_metrics(y_train, y_pred_train, y_test, y_pred_test)
# Out:
# Accuracy Train:0.9802197802197802 - Accuracy Test:0.9824561403508771 - Precision:0.9767441860465116 - Recall:0.9767441860465116 - F1_Score:0.9767441860465116
#
# Confusion_Matrix:
# [[70  1]
#  [ 1 42]]
#
# Classification_Report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99        71
#            1       0.98      0.98      0.98        43
#
#     accuracy                           0.98       114
#    macro avg       0.98      0.98      0.98       114
# weighted avg       0.98      0.98      0.98       114

# %%
import seaborn as sns
confusion_m = confusion_matrix(y_test, y_pred_test)
plt.figure(figsize=(3,2))
sns.heatmap(confusion_m, annot=True, fmt ='d', cmap='hot')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix SVM')
plt.show()

# %% [markdown]
# ## 5. Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression(C=1, penalty='l2', solver='lbfgs', class_weight='balanced')
lr.fit(X_train, y_train)
# Out:
# e:\Python Git\ML\breast_cancer_classification\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:1135: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', and C=np.inf instead of penalty=None.
#   warnings.warn(
# LogisticRegression(C=1, class_weight='balanced', penalty='l2')

# %%
y_pred_train = lr.predict(X_train)
y_pred_test = lr.predict(X_test)

accuracy_train_lr, accuracy_test_lr, precision_lr, recall_lr, f1_lr = evaluation_metrics(y_train, y_pred_train, y_test, y_pred_test)
# Out:
# Accuracy Train:0.9758241758241758 - Accuracy Test:0.9736842105263158 - Precision:0.9545454545454546 - Recall:0.9767441860465116 - F1_Score:0.9655172413793104
#
# Confusion_Matrix:
# [[69  2]
#  [ 1 42]]
#
# Classification_Report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.97      0.98        71
#            1       0.95      0.98      0.97        43
#
#     accuracy                           0.97       114
#    macro avg       0.97      0.97      0.97       114
# weighted avg       0.97      0.97      0.97       114

# %%
import seaborn as sns
confusion_m = confusion_matrix(y_test, y_pred_test)
plt.figure(figsize=(3,2))
sns.heatmap(confusion_m, annot=True, fmt ='d', cmap='hot')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix Logistic Regression')
plt.show()

# %% [markdown]
# ## 6. ANN (Artificial Neural Network)

# %%
from sklearn.neural_network import MLPClassifier

mlp = MLPClassifier(hidden_layer_sizes=100, max_iter=600, activation='relu', solver='adam')
mlp.fit(X_train, y_train)
# Out:
# MLPClassifier(hidden_layer_sizes=100, max_iter=600)

# %%
y_prob = mlp.predict_proba(X_test)[:,1]
for threshold in [0.5, 0.4, 0.3, 0.2]:
    y_pred_test = (y_prob > threshold).astype(int)
    print("Threshold:", threshold, "Recal:", recall_score(y_test, y_pred_test))
# Out:
# Threshold: 0.5 Recal: 0.9534883720930233
# Threshold: 0.4 Recal: 0.9534883720930233
# Threshold: 0.3 Recal: 0.9767441860465116
# Threshold: 0.2 Recal: 0.9767441860465116

# %%
threshold = 0.3
y_pred_test = (y_prob > threshold).astype(int)

accuracy_train_mlp, accuracy_test_mlp, precision_mlp, recall_mlp, f1_mlp = evaluation_metrics(y_train, y_pred_train, y_test, y_pred_test)
# Out:
# Accuracy Train:0.9758241758241758 - Accuracy Test:0.9736842105263158 - Precision:0.9545454545454546 - Recall:0.9767441860465116 - F1_Score:0.9655172413793104
#
# Confusion_Matrix:
# [[69  2]
#  [ 1 42]]
#
# Classification_Report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.97      0.98        71
#            1       0.95      0.98      0.97        43
#
#     accuracy                           0.97       114
#    macro avg       0.97      0.97      0.97       114
# weighted avg       0.97      0.97      0.97       114

# %%
import seaborn as sns
confusion_m = confusion_matrix(y_test, y_pred_test)
plt.figure(figsize=(3,2))
sns.heatmap(confusion_m, annot=True, fmt ='d', cmap='hot')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix ANN')
plt.show()

# %% [markdown]
# ## Model Performance Comparison

# %% [markdown]
# ### Accuracy (Train & Test)

# %%
accuracy_train = [accuracy_train_knn, accuracy_train_dt, accuracy_train_rf, accuracy_test_lr, accuracy_train_svm, accuracy_train_mlp]
accuracy_test = [accuracy_test_knn, accuracy_test_dt, accuracy_test_rf, accuracy_test_lr, accuracy_test_svm, accuracy_test_mlp]
models = ["KNN", "DT", "RF", "LR", "SVM", "ANN"]
plt.figure(figsize=(4,3))
x = np.arange(len(models))
plt.bar(x, accuracy_train, width=0.4, label="Train")
plt.bar(x + 0.4, accuracy_test, width=0.4, label="Test", color="orange")
plt.xticks(x + 0.2, models)
plt.legend(loc='upper left', bbox_to_anchor=(1,1))
plt.title('Accuracy Comparison of ML Models (Train & Test)')
plt.xlabel("ML Models")
plt.ylabel('Accuracy Score')
plt.grid()
plt.show()

# %% [markdown]
# ### Precision

# %%
precision = [precision_knn, precision_dt, precision_rf, precision_lr, precision_svm, precision_mlp]
models = ["KNN", "DT", "RF", "LR", "SVM", "ANN"]
plt.figure(figsize=(4,3))
colors = plt.cm.Set2(range(len(models)))
plt.bar(models, precision, color=colors)
plt.title('Precision Comparison of ML Models (Test Data)')
plt.xlabel("ML Models")
plt.ylabel('Precision')
plt.grid()
plt.show()

# %% [markdown]
# ### Recall

# %%
recall = [recall_knn, recall_dt, recall_rf, recall_lr, recall_svm, recall_mlp]
models = ["KNN", "DT", "RF", "LR", "SVM", "ANN"]
plt.figure(figsize=(4,3))
colors = plt.cm.Set2(range(len(models)))
plt.bar(models, recall, color=colors)
plt.title('Recall Comparison of ML Models (Test Data)')
plt.xlabel("ML Models")
plt.ylabel('Recall')
plt.grid()
plt.show()

# %% [markdown]
# ### F1-Score

# %%
f1 = [f1_knn, f1_dt, f1_rf, f1_lr, f1_svm, f1_mlp]
models = ["KNN", "DT", "RF", "LR", "SVM", "ANN"]
plt.figure(figsize=(4,3))
colors = plt.cm.Set2(range(len(models)))
plt.bar(models, f1, color=colors)
plt.title('F1-Score Comparison of ML Models (Test Data)')
plt.xlabel("ML Models")
plt.ylabel('F1_Score')
plt.grid()
plt.show()
